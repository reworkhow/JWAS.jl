# %% [markdown]
# <nav class="navbar navbar-inverse">
#     <ul class="nav navbar-nav">
#       <li><a href="#">Home</a></li>
#       <li><a href="#">Examples</a></li>
#       <li><a href="#">Theory</a></li>
#       <li><a href="https://github.com/reworkhow/JWAS.jl">Source Code</a></li>
#       <li><a href="http://julialang.org/">about Julia</a></li>
#     </ul>
# </nav>
#
# <div class="span5 alert alert-success">
#   <h1><font color="black" size="7">JWAS</font></h1>
#   <p><font color="black" size="4">Julia for Whole-genome Analyses Software </font></p>
# </div>
#
# <div class="container">
#   <div class="row">
#     <div class="col-sm-3">
#       <h3>Bayesian Regression</h3>
#      <ul>
#       <li>MCMC</li>
#       <li>BayesABC</li>
#      </ul>
#      </div>
#     <div class="col-sm-3">
#       <h3>Basic Analyses</h3>
#      <ul>
#       <li>Linear Mixed Effects Model</li>
#       <li>Multivariate Analyses</li>
#      </ul>
#     </div>
#     <div class="col-sm-3">
#       <h3>Genomic Data</h3>
#      <ul>
#       <li> Genomic Prediction</li>
#       <li> Genome-wide Association Studies </li>
#      </ul>
#     </div>
#  </div>
# </div>
#
# <br>
#
# <button type="button" class="btn btn-lg btn-default">Julia</button>
# <button type="button" class="btn btn-lg btn-primary">Linear Mixed Effects Model</button>
# <button type="button" class="btn btn-lg btn-success">Multivariate</button>
# <button type="button" class="btn btn-lg btn-warning">Bayessian Regression</button>
# <br>
# <button type="button" class="btn btn-lg btn-danger">Whole-genome Data</button>
# <button type="button" class="btn btn-lg btn-info">Missing Phenotypes</button>
# <button type="button" class="btn btn-lg btn-danger active disabled">BayesABC</button>
#
# <a href="https://github.com/reworkhow/JWAS.jl/issues">On-going development <span class="badge">3</span></a><br>
# <a href="https://github.com/reworkhow/JWAS.jl/issues">Issues <span class="badge">2</span></a>

# %% [markdown]
# <div style="float:right; \">
# <img src="QTL.jpg"
#  align=right style="float:right; margin-left: 5px; margin-top: -10px"
#  />
# </div>
#
# ### Read At First
#
# * [Read At First](0.read_at_first.ipynb)
#
#
# ### Some Theory
#
# * [Univariate Bayesian Linear Regression Model](Theory/theory.ipynb) (on-going)
#
#
# ### Examples
#
# * Section 1:
#   &nbsp; **Univariate Bayesian Linear Regression Model **
#     * [1.1](ST/1.1.Univariate_Linear_Mixed_Effects_Model.ipynb) &nbsp; The Univariate Linear Mixed Effects Model
#     * [1.2](ST/1.2.Univariate_Linear_Additive_Genetic_Model.ipynb) &nbsp; The Univariate Linear Additive Genetic Model (with Maternal Effects)
#     * [1.3](ST/1.3.Univariate_Linear_Mixed_Effects_Model_with_Genomic_Data.ipynb) &nbsp; The Univariate Linear Mixed Effects Model with <b>Genomic Data</b>
#
# <br>
#
#
# * Section 2:
#   &nbsp; **Multivariate (multi-trait) Bayesian Linear Regression Model **
#     * [2.1](MT/2.1.Multivariate_Linear_Mixed_Effects_Model.ipynb) &nbsp; The Multivariate Linear Mixed Effects Model
#     * [2.2](MT/2.2.Multivariate_Linear_Additive_Genetic_Model.ipynb) &nbsp; The Multivariate Linear Additive Genetic Model (with Maternal Effects)
#     * [2.3](MT/2.3.Multivariate_Linear_Mixed_Effects_Model_with_Genomic_Data.ipynb) &nbsp; The Multivariate Linear Mixed Effects Model with <b>Genomic Data</b>
#
# <br>
# * Section 3:
#   &nbsp; **SSBR (beta version) **
#     * [3.1](SSBR.ipynb) &nbsp; SSBR
#
# <br><br><br><br><br><br><br><br>
#
#
# <!---
# <ul class="pagination pagination-lg">
#   <li><a href="#">1</a></li>
#   <li><a href="#">2</a></li>
#   <li><a href="#">3</a></li>
#   <li><a href="#">4</a></li>
#   <li><a href="#">5</a></li>
# </ul>
#
# <ul class="pagination pagination-sm">
#
# <ul class="breadcrumb">
#   <li><a href="www.google.com">Univariate Basics</a></li>
#   <li><a href="#">Univariate Additive Genetic Model</a></li>
#   <li><a href="#">Univariate Genomic Data</a></li>
# </ul>
# <ul class="breadcrumb">
#   <li><a href="www.google.com">Multivariate Basics</a></li>
#   <li><a href="#">Multivariate Additive Genetic Model</a></li>
#   <li><a href="#">Multivariate Genomic Data</a></li>
# </ul>
#
# <ul class="pager">
#   <li><a href="#">Previous</a></li>
#   <li><a href="#">Next</a></li>
# </ul>
# --->
#
# <!---
#
# <div class="jumbotron" style="background:yellow;">
#   <h1>JWAS</h1>
#   <p>Julia for Whole-genome Analyses Software </p>
# </div>
# --->
#
# <!---
# <nav class="navbar navbar-default">
#     <ul class="nav navbar-nav">
#       <li class="active"><a href="#">Home</a></li>
#       <li><a href="#">Examples</a></li>
#       <li><a href="#">Theory</a></li>
#       <li><a href="#">Source Code</a></li>
#     </ul>
# </nav>
# --->
